# %%
import numpy as np
# import tensorflow as tf
# from tensorflow.keras import Sequential
# from tensorflow.keras.layers import Dense

import numpy as np
# import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 import tensorflow as tf
#       3 from tensorflow.keras import Sequential
#       4 from tensorflow.keras.layers import Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
#iinput 3 samples

np.random.seed(100)

X = np.array([
    [1.0,  2.0,  3.0,  2.5],
    [2.0,  5.0, -1.0,  2.0],
    [-1.5, 2.7,  3.3, -0.8]
])

np.random.seed(100)

W1 = np.random.rand(4,3) #weight matrix for layer 1

b1 = [0.4, 0.3, 0.1] #bais of layer 1

h1 = np.dot(X,W1) + b1 #three outputs from 3 samples

W2 = np.random.rand(3,2) #weight matrix for layer 2

b2 = [0.4, 0.6] #output bais
 
h1 @ W2 + b2 #output of second layer

# %%
X = np.array([
    [1.0,  2.0,  3.0,  2.5],
    [2.0,  5.0, -1.0,  2.0],
    [-1.5, 2.7,  3.3, -0.8]
])

# Dummy regression targets (just for demo)
y = np.array([
    [1.0, 0.5, 0.2],
    [0.3, 1.2, 0.7],
    [0.8, 0.1, 1.0]
])

model = Sequential([
    Dense(5, input_shape=(4,), activation=None),  # Hidden layer
    Dense(3, activation=None)                     # Output layer
])

y_pred = model(X)
print(y_pred.numpy())

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(8, activation="relu", input_shape=(4,)),
    tf.keras.layers.Dense(4, activation="relu"),
    tf.keras.layers.Dense(3)
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
    loss="mse"
)

model.fit(X, y, epochs=100)

predictions = model.predict(X)
print(predictions)
