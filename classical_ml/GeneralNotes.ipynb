# %% [markdown]
# ### Important Steps
#
# 1. 1nitalizing the model instance/class - with class attributes
# regm = LinearRegression()
#
# 2. Fit the input and Target to the model instance using the fit method using the training data
# regm.fit(X_train, y_train)
#
# 3. Predict the y using the predict method - test data
# regm.predict(X_test)
#
# 4. Analyse the Evaluation Metrics using the existing methods
# regm.summary()
