# %%
print("Hello!")
# Out:
# Hello!

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.scatterplot(x=np.array([2,3, 9]), y=np.array([4,4.5, 8]), s=250, marker="*", color='r')
plt.grid(True)
plt.show()
